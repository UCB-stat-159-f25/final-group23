# %% [markdown]
# # Data Processing

# %%
# Basic Imports

import matplotlib.pyplot as plt
import pandas as pd
import kagglehub

# %% [markdown]
# ## Load Dataset

# %%
dataset_path = kagglehub.dataset_download("yelp-dataset/yelp-dataset")

chunks = pd.read_json(
    f"{dataset_path}/yelp_academic_dataset_review.json",
    lines=True,
    chunksize=100_000
)

dfs = []
for chunk in chunks:
    dfs.append(chunk[["review_id", "stars", "text", "date"]])
    if len(dfs) >= 3:
        break

df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ## Sort Dataset and Choose Subset

# %%
df["date"] = pd.to_datetime(df["date"])

df = df.sort_values(
    by=["date", "review_id"],
    ascending=[False, True]
)

df_subset = df.iloc[:20000].reset_index(drop=True)

# %% [markdown]
# ## Create Label for Binary Classification
#
# We chose rating of 1~3 to be negative review, and 4~5 to be positive review. In the future, we may choose different binary classes to see how results differ.

# %%
df_subset["label"] = (df_subset["stars"] >= 4).astype(int)
df_subset.to_csv("data/yelp_reviews_subset.csv", index=False)

# %% [markdown]
# ## Subset Summary

# %%
df_subset.head()
# Out:
#                 review_id  stars  \
# 0  igUar2sMmvX7Ps1AbvQXgg      1
# 1  peB3hSTWXgpsc2SCaBEPtA      5
# 2  wrLFWRBu_JkD6CW5XpLj5w      5
# 3  _Mgbav5Q7LD1FZfIvueQXw      5
# 4  j0dc6B6xEXTp_zYMuJ3ysQ      1
#
#                                                 text                date  \
# 0  This is the worst Walmart ever conceived by hu... 2020-07-07 22:59:20
# 1  I've always loved Outback and the fact that th... 2020-06-05 20:58:29
# 2  LOVE THIS PLACE!! Such amazing ice cream at a ... 2020-05-13 02:10:17
# 3  Took both my pups for a way ovetdue grooming. ... 2020-05-11 01:18:16
# 4  i went to get a chicken sandwich, and being al... 2020-05-04 01:57:38
#
#    label
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0

# %%
print("Subset shape:", df_subset.shape)
print("\nStar rating distribution:")
display(df_subset["stars"].value_counts().sort_index())

print("\nLabel distribution (0 = negative, 1 = positive):")
display(df_subset["label"].value_counts())
# Out:
# Subset shape: (20000, 5)
#
# Star rating distribution:
# stars
# 1     2381
# 2     1391
# 3     1718
# 4     3668
# 5    10842
# Name: count, dtype: int64
# Label distribution (0 = negative, 1 = positive):
# label
# 1    14510
# 0     5490
# Name: count, dtype: int64
